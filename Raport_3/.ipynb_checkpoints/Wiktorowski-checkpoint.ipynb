# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from statistics import stdev
import scipy.stats as sp
from scipy.stats import median_abs_deviation, skew, kurtosis
from scipy.stats import norm, logistic, laplace
from scipy.stats import pearsonr
from scipy.special import erf
import seaborn as sns; sns.set()

# %%
def equalize(df, d): #funkcja ta skaluje ceny miedzi do cen za tonę
    col_names = [col for col in df.columns][1:]
    col_names.remove('Volume')
    for name in col_names:
        df[name] = df[name]*d
    return df

def draw_stock(df, clr, title): #funkcja rysuje wykres cen
    fig, ax = plt.subplots(figsize = (15, 4))
    plt.xticks(rotation = 45)
    xloc = plt.MaxNLocator(9)
    ax.xaxis.set_major_locator(xloc)
    dates = df['Date'].values[::-1]
    prices = df['Open'].values[::-1]
    plt.plot(dates, prices, color = clr)
    plt.ylabel('USD')
    plt.title(title, fontsize = 25)
    plt.show()
    
def draw_ret(df, clr, title): #funkcja rysuje wykres log stóp zwrotu
    fig, ax = plt.subplots(figsize = (15, 4))
    plt.xticks(rotation = 45)
    xloc = plt.MaxNLocator(9)
    ax.xaxis.set_major_locator(xloc)
    dates = df['Date'].values[::-1][:-1]
    prices1 = df['Open'].values[::-1][1:]
    prices2 = df['Open'].values[::-1][:-1]
    r = np.log(prices1/prices2)
    plt.plot(dates, r, color = clr, lw=1)
    plt.title(title, fontsize = 25)
    plt.show()

# %% [markdown]
# # Przypomnienie

# %% [markdown]
# ### Aluminium

# %%
aluminium_ = pd.read_csv('../data/aluminium.csv', sep = ',', encoding = 'latin-1') #ceny aluminium (przed ucięciem)
idx = aluminium_.index[aluminium_['Date'] == '07/01/2019'].tolist()[0] #idx = 952
aluminium = aluminium_.drop(aluminium_.index[(idx - 2):1259]) #ceny aluminium (po ucięciu)
aluminium
# Out:
#            Date  Close/Last  Volume     Open     High      Low
# 0    04/12/2023     2328.50  1205.0  2311.00  2335.00  2293.50
# 1    04/11/2023     2306.75  1979.0  2333.75  2335.50  2302.50
# 2    04/10/2023     2348.00  2215.0  2348.00  2348.00  2348.00
# 3    04/06/2023     2338.25  1373.0  2355.00  2359.50  2329.25
# 4    04/05/2023     2370.00     NaN  2370.00  2370.00  2370.00
# ..          ...         ...     ...      ...      ...      ...
# 945  07/11/2019     1865.00     5.0  1865.00  1865.00  1865.00
# 946  07/10/2019     1861.50     NaN  1861.50  1861.50  1861.50
# 947  07/09/2019     1853.50    15.0  1855.00  1875.00  1855.00
# 948  07/08/2019     1813.25     NaN  1813.25  1813.25  1813.25
# 949  07/05/2019     1806.75     NaN  1806.75  1806.75  1806.75
#
# [950 rows x 6 columns]

# %%
draw_stock(aluminium, 'silver', 'Ceny aluminium')

# %%
s_aluminium = np.array(aluminium['Open'].values)
r_aluminium = np.log(s_aluminium[1:]/s_aluminium[:-1]) #tu są logarytmiczne stopy zwrotu
t_aluminium = np.array([*range(len(r_aluminium))])
draw_ret(aluminium, 'silver', 'Logarytmiczne stopy zwrotu')

# %%
ss_aluminium = stdev(r_aluminium)
r_aluminium_sr = np.mean(r_aluminium)
print('Średnia: ' + str(np.mean(r_aluminium)))
print('Odchylenie standardowe: ' + str(stdev(r_aluminium)))
print('Korelacja: ' + str(np.corrcoef(r_aluminium, t_aluminium)[0][1]))
print('Przeciętna stopa zwrotu: ' + str(r_aluminium_sr))
# Out:
# Średnia: -0.000259379009600938
# Odchylenie standardowe: 0.016536765157234286
# Korelacja: -0.016641196537114555
# Przeciętna stopa zwrotu: -0.000259379009600938

# %% [markdown]
# ### Miedź

# %%
copper_ = pd.read_csv('../data/copper.csv', sep = ',', encoding = 'latin-1')
copper = equalize(copper_.drop(copper_.index[idx:1260]).drop(copper_.index[0:2]), 2204.623)

# %%
copper
# Out:
#            Date   Close/Last  Volume         Open         High          Low
# 2    04/12/2023  8997.066463   88325  8883.528378  9012.498824  8783.218032
# 3    04/11/2023  8861.482148   81243  8789.831901  8937.541642  8769.990294
# 4    04/10/2023  8766.683360   53745  8858.175214  8905.574609  8736.920949
# 5    04/06/2023  8852.663657   86075  8779.911098  8887.937625  8754.557933
# 6    04/05/2023  8788.729590   65931  8761.171802  8809.673508  8655.349898
# ..          ...          ...     ...          ...          ...          ...
# 947  07/11/2019  5924.924313   60433  5928.231247  5948.072854  5905.082705
# 948  07/10/2019  5939.254362   83259  5793.749244  5951.379789  5787.135375
# 949  07/09/2019  5787.135375   74241  5858.785623  5862.092557  5758.475276
# 950  07/08/2019  5862.092557   56450  5885.241099  5928.231247  5852.171754
# 951  07/05/2019  5866.501803   66334  5903.980394  5924.924313  5830.125523
#
# [950 rows x 6 columns]

# %%
draw_stock(copper, 'peru', 'Ceny miedzi')

# %%
s_copper = np.array(copper['Open'].values)
r_copper = np.log(s_copper[1:]/s_copper[:-1]) #tu są logarytmiczne stopy zwrotu
t_copper = np.array([*range(len(r_copper))])
draw_ret(copper, 'peru', 'Logarytmiczne stopy zwrotu')

# %%
ss_copper = stdev(r_copper)
r_copper_sr = np.mean(r_copper)
print('Średnia: ' + str(np.mean(r_copper)))
print('Odchylenie standardowe: ' + str(stdev(r_copper)))
print('Korelacja: ' + str(np.corrcoef(r_copper, t_copper)[0][1]))
print('Przeciętna stopa zwrotu: ' + str(r_copper_sr))
# Out:
# Średnia: -0.0004305290321532628
# Odchylenie standardowe: 0.014926237434109913
# Korelacja: -0.014642310753235934
# Przeciętna stopa zwrotu: -0.0004305290321532628

# %% [markdown]
# # Stopa zwrotu, ryzyko portfela

# %% [markdown]
# Ustalamy wagi portfela odpowiednio $w1 = 0,55$ dla miedzi, oraz $w2 = 0,45$ dla aluminium.

# %%
R1 = r_copper
R2 = r_aluminium
w1 = 0.55
w2 = 0.45

# %% [markdown]
# **Stopa zwrotu**
# $$R_p = w_1R_1 + w_2R_2$$

# %%
Rp = w1*R1 + w2*R2

# %% [markdown]
# **Oczekiwana stopa zwrotu**
# $$\text{E}[R_p] = w_1\text{E}[R_1] + w_2\text{E}[R_2]$$

# %%
Rp_sr = np.mean(Rp)
Rp_sr
# Out:
# -0.0003535115220047165

# %% [markdown]
# **Miary ryzyka**

# %%
sp = stdev(Rp)
print('Odchylenie standardowe: ' + str(stdev(Rp)))
print('Odchylenie przeciętne: ' + str(sum(abs(Rp - np.mean(Rp)))/len(Rp)))
print('Odchylenie ćwiartkowe: ' + str(1/2 * (np.quantile(Rp, .75) - np.quantile(Rp, .25))))
# Out:
# Odchylenie standardowe: 0.012341154886676633
# Odchylenie przeciętne: 0.009154336769992073
# Odchylenie ćwiartkowe: 0.006865774865488859

# %% [markdown]
# # Możliwe portfele

# %%
def portfolio(Ra, Rb):
    w1 = np.linspace(.01, .99, 99)
    w2 = 1 - w1
    E = []
    s = []
    for w1, w2 in zip(w1, w2):
        s.append(stdev(w1*Ra + w2*Rb))
        E.append(w1*np.mean(Ra) + w2 *np.mean(Rb))
    s = np.array(s)
    E = np.array(E)
    idx = np.where(s == min(s))[0][0]
    E_min = E[idx]
    return s, E, min(s), E_min, idx

# %%
s, E, s_min, E_min, idx = portfolio(R1, R2)

fig, ax = plt.subplots(figsize = (10, 6))
plt.plot(s, E, color = 'darkgreen', label = 'Portfel o min. ryzyku')
plt.title('Możliwe portfele')
plt.xlabel('$\sigma_p$')
plt.ylabel('$E[R_p]$')
plt.legend()
plt.show()

# %%
s, E
# Out:
# (array([0.01640812, 0.01628076, 0.01615474, 0.01603008, 0.01590681,
#         0.01578497, 0.01566459, 0.01554569, 0.01542833, 0.01531253,
#         0.01519832, 0.01508575, 0.01497485, 0.01486566, 0.01475821,
#         0.01465255, 0.01454872, 0.01444674, 0.01434667, 0.01424854,
#         0.0141524 , 0.01405827, 0.01396622, 0.01387627, 0.01378846,
#         0.01370285, 0.01361946, 0.01353834, 0.01345954, 0.01338309,
#         0.01330903, 0.01323741, 0.01316826, 0.01310162, 0.01303753,
#         0.01297603, 0.01291716, 0.01286094, 0.01280743, 0.01275664,
#         0.01270862, 0.01266339, 0.01262099, 0.01258144, 0.01254477,
#         0.01251101, 0.01248018, 0.01245229, 0.01242738, 0.01240546,
#         0.01238654, 0.01237064, 0.01235777, 0.01234794, 0.01234115,
#         0.01233742, 0.01233675, 0.01233912, 0.01234456, 0.01235304,
#         0.01236456, 0.01237912, 0.0123967 , 0.01241729, 0.01244088,
#         0.01246745, 0.01249698, 0.01252945, 0.01256483, 0.01260311,
#         0.01264425, 0.01268823, 0.01273501, 0.01278458, 0.01283689,
#         0.01289191, 0.01294961, 0.01300995, 0.01307289, 0.01313841,
#         0.01320645, 0.01327698, 0.01334997, 0.01342536, 0.01350313,
#         0.01358322, 0.01366561, 0.01375024, 0.01383708, 0.01392608,
#         0.01401721, 0.01411042, 0.01420568, 0.01430293, 0.01440215,
#         0.01450328, 0.0146063 , 0.01471116, 0.01481782]),
#  array([-0.00026109, -0.0002628 , -0.00026451, -0.00026623, -0.00026794,
#         -0.00026965, -0.00027136, -0.00027307, -0.00027478, -0.00027649,
#         -0.00027821, -0.00027992, -0.00028163, -0.00028334, -0.00028505,
#         -0.00028676, -0.00028847, -0.00029019, -0.0002919 , -0.00029361,
#         -0.00029532, -0.00029703, -0.00029874, -0.00030046, -0.00030217,
#         -0.00030388, -0.00030559, -0.0003073 , -0.00030901, -0.00031072,
#         -0.00031244, -0.00031415, -0.00031586, -0.00031757, -0.00031928,
#         -0.00032099, -0.0003227 , -0.00032442, -0.00032613, -0.00032784,
#         -0.00032955, -0.00033126, -0.00033297, -0.00033469, -0.0003364 ,
#         -0.00033811, -0.00033982, -0.00034153, -0.00034324, -0.00034495,
#         -0.00034667, -0.00034838, -0.00035009, -0.0003518 , -0.00035351,
#         -0.00035522, -0.00035693, -0.00035865, -0.00036036, -0.00036207,
#         -0.00036378, -0.00036549, -0.0003672 , -0.00036892, -0.00037063,
#         -0.00037234, -0.00037405, -0.00037576, -0.00037747, -0.00037918,
#         -0.0003809 , -0.00038261, -0.00038432, -0.00038603, -0.00038774,
#         -0.00038945, -0.00039116, -0.00039288, -0.00039459, -0.0003963 ,
#         -0.00039801, -0.00039972, -0.00040143, -0.00040315, -0.00040486,
#         -0.00040657, -0.00040828, -0.00040999, -0.0004117 , -0.00041341,
#         -0.00041513, -0.00041684, -0.00041855, -0.00042026, -0.00042197,
#         -0.00042368, -0.00042539, -0.00042711, -0.00042882]))

# %% [markdown]
# # Portfel o minimalnym ryzyku

# %%
fig, ax = plt.subplots(figsize = (10, 6))
plt.plot(s, E, color = 'darkgreen', label = 'Możliwe portfele')
plt.scatter(s_min, E_min, color = 'firebrick', label = 'Portfel o min. ryzyku')
plt.title('Możliwe portfele')
plt.xlabel('$\sigma_p$')
plt.ylabel('$E[R_p]$')
plt.legend()
plt.show()

# %%
s_min, E_min
# Out:
# (0.012336746004776326, -0.00035693452245576316)

# %%
round(np.linspace(.01, .99, 99)[idx], 2) #waga 'minimalna' dla miedzi
# Out:
# 0.57

# %%
round((1 - np.linspace(.01, .99, 99))[idx], 2) #waga 'minimalna' dla aluminium
# Out:
# 0.43

# %% [markdown]
# Otrzymujemy portfel o minimalnym ryzyku dla wag odpowiednio 0,57 dla miedzi i 0,43 dla aluminium. Ryzyko takiego portfela wynosi w przybliżeniu 1,24% (zaokrąglam w górę).

# %% [markdown]
# # Portfel o minimalnym ryzyku przy ustalonej stopie zwrotu

# %%
def portfolio2(R1, R2, rate):
    w1 = np.linspace(.001, .999, 999)
    w2 = 1 - w1
    E = []
    s = []
    for w1, w2 in zip(w1, w2):
        s.append(stdev(w1*R1 + w2*R2))
        E.append(w1*np.mean(R1) + w2*np.mean(R2))
    s = np.array(s)
    E = np.array(E)
    d_rate = abs(E - rate)
    idx = np.where(d_rate == min(d_rate))[0][0]
    E_min = E[idx]
    return s, E, s[idx], E_min, idx

# %%
s, E, s_min, E_min, idx = portfolio2(R1, R2, -0.0003)

portfig, ax = plt.subplots(figsize = (10, 6))
plt.plot(s, E, color = 'darkgreen', label = 'Możliwe portfele')
plt.axline((min(s), E_min), (max(s), E_min), linestyle = 'dashdot', color = 'gray', 
          label = 'Stopa wolna od ryzyka')
plt.scatter(s_min, E_min, color = 'firebrick', label = 'Portfel o min. ryzyku')
plt.title('Możliwe portfele')
plt.xlabel('$\sigma_p$')
plt.ylabel('$E[R_p]$')
plt.legend()
plt.show()

# %%
s_min, E_min
# Out:
# (0.013903027982924582, -0.000299941564945839)

# %%
round(np.linspace(.001, .999, 999)[idx], 2) #waga 'minimalna' dla miedzi
# Out:
# 0.24

# %%
round((1 - np.linspace(.001, .999, 999))[idx], 2) #waga 'minimalna' dla aluminium
# Out:
# 0.76

# %% [markdown]
# # Portfel rynkowy

# %%
def portfolio3(R1, R2, R_f,wf):
    w1 = np.linspace(0, 1, 999)
    w2 = 1 - w1
    E = []
    s = []
    for w1, w2 in zip(w1, w2):
        
        s.append(stdev((w1*R1 + w2*R2)*(1-wf)+wf*R_f))
        E.append(np.mean((w1*R1 + w2*R2)*(1-wf)+wf*R_f))
    s = np.array(s)
    E = np.array(E)
    ss = (E - R_f)/s
    idx = np.where(max(ss))[0][0]
    E_max = E[idx]
    return s, E, s[idx], E_max, idx

# %%
s, E, s_min, E_min, idx = portfolio3(R1, R2, -0.3,0.009)

portfig, ax = plt.subplots(figsize = (10, 6))
plt.plot(s, E, color = 'darkgreen', label = 'Możliwe portfele')
plt.scatter(s_min, E_min, color = 'firebrick', label = 'Portfel o min. ryzyku')
plt.title('Możliwe portfele')
plt.xlabel('$\sigma_p$')
plt.ylabel('$E[R_p]$')
plt.legend()
plt.show()

# %% [markdown]
# # MODEL JEDNOWSKAŹNIKOWY

# %% [markdown]
# ### Jako trzecią zmienną bierzemy pod uwagę logarytmiczne stopy zwrotu ropy...

# %%
oil_ = pd.read_csv('../data/crudeoil.csv', sep = ',', encoding = 'latin-1') #ceny aluminium (przed ucięciem)
idx_oil_ = oil_.index[oil_['Date'] == '07/01/2019'].tolist()[0] #idx = 954
oil = equalize(oil_.drop(oil_.index[(idx_oil_ - 2):1261]).drop(oil_.index[0:2]), 1/0.156444) #ceny aluminium (po ucięciu)
num = oil._get_numeric_data()
neg_idx = num.index[num['Open'] < 0].tolist()[0] #752
num
oil['Open'] = oil['Open'].where(oil['Open'] > 0, (num.loc[751, "Open"] + num.loc[753, "Open"])/2)

# %%
oil
# Out:
#            Date  Close/Last  Volume        Open        High         Low
# 2    04/12/2023  532.203216  323826  520.569661  533.929074  519.546931
# 3    04/11/2023  521.144946  282640  510.598041  521.528470  507.338089
# 4    04/10/2023  509.703153  238729  514.561121  519.163407  508.872184
# 5    04/06/2023  515.839534  240865  513.730153  517.501470  509.127867
# 6    04/05/2023  515.264248  240802  517.821073  519.291248  509.575311
# ..          ...         ...     ...         ...         ...         ...
# 947  07/11/2019  384.802230  544988  386.336325  389.532357  384.418706
# 948  07/10/2019  386.272404  658286  373.296515  386.911611  372.976912
# 949  07/09/2019  369.653039  518258  367.927182  377.770960  366.201324
# 950  07/08/2019  368.566388  510184  369.269515  373.680039  366.265245
# 951  07/05/2019  367.607578  681543  362.749610  369.589118  359.809261
#
# [950 rows x 6 columns]

# %%
oil[749:752]
# Out:
#            Date  Close/Last  Volume        Open        High         Low
# 751  04/21/2020   57.912096   12250   72.549922   88.594002   56.953287
# 752  04/20/2020 -240.533354  148427  100.195597 -225.000639 -257.728005
# 753  04/17/2020  116.783002  213600  127.841272  129.247526  110.646621

# %%
draw_stock(oil, 'black', 'Ceny ropy') # ceny za tonę metryczną

# %%
s_oil = np.array(oil['Open'].values)
r_oil = np.log(s_oil[1:]/s_oil[:-1]) #tu są logarytmiczne stopy zwrot
t_oil = np.array([*range(len(r_oil))])
draw_ret(oil, 'black', 'Logarytmiczne stopy zwrotu')

# %%
def corr(r1, r2, title, show = False):
    sx = stdev(r1)
    sy = stdev(r2)
    r = np.corrcoef(r1, r2)[0][1]
    
    a = r*sy/sx
    b = np.mean(r2) - a*np.mean(r1)
    
    if show:
        fig, ax = plt.subplots(figsize = (12, 8))
        plt.scatter(r1, r2, color = 'g', edgecolors = 'black', linewidth = 1, alpha = 0.2)
        plt.plot(r1, a*r1 + b, color = 'crimson', label = 'Prosta regresji')
        plt.legend()
        plt.title(title, fontsize = 20)
        plt.show()

# %%
np.corrcoef(r_oil, r_copper)[0][1]
# Out:
# 0.2592009662315715

# %%
sx = stdev(r_oil)
sy = stdev(r_copper)
r = np.corrcoef(r_oil, r_copper)[0][1]
a = r*sy/sx
b = np.mean(r_copper) - np.mean(r_oil)*a
plt.scatter(r_oil, r_copper)
plt.plot(np.linspace(-0.15, 0.15, 949), 0.8*np.linspace(-0.15, 0.15, 949) + b, color = 'r')

# %%
sx = stdev(r_oil)
sy = stdev(r_aluminium)
r = np.corrcoef(r_oil, r_aluminium)[0][1]
a = r*sy/sx
b = np.mean(r_aluminium) - np.mean(r_oil)*a
plt.scatter(r_oil, r_aluminium)
plt.plot(np.linspace(-0.1, 0.1, 949), 0.3*np.linspace(-0.15, 0.15, 949) + b, color = 'r')

# %%
corr(r_copper, r_oil, 'Korelacja stóp zwrotu miedzi i ropy', True)

# %%
corr(r_oil, r_copper, 'Korelacja stóp zwrotu miedzi i ropy', True)

# %%
import scipy
corr(scipy.stats.norm.rvs(size = 1000, loc = 0, scale = 9), 
     scipy.stats.norm.rvs(size = 1000, loc = 0, scale = 1), 'Korelacja stóp zwrotu miedzi i ropy', True)

# %%
print('Korelacja miedź-ropa: ' + str(np.corrcoef(r_copper, r_oil)[0][1]))
# Out:
# Korelacja miedź-ropa: 0.2592009662315715

# %%
a1, b1 = corr(r_oil, r_copper, 'Korelacja stóp zwrotu miedzi i ropy')

# %%
a1, b1
# Out:
# (0.09728795150036447, -0.00039349903407704995)

# %%
corr(r_oil, r_aluminium, 'Korelacja stóp zwrotu aluminium i ropy', True)
# Out:
# (0.0503006105934663, -0.00024023345781592158)

# %%
print('Korelacja aluminium-ropa: ' + str(np.corrcoef(r_oil, r_aluminium)[0][1]))
# Out:
# Korelacja aluminium-ropa: 0.12096245734824987

# %%
a2, b2 = corr(r_oil, r_aluminium, 'Korelacja stóp zwrotu aluminium i ropy')

# %%
a2, b2
# Out:
# (0.05030061059346632, -0.0002402334578159216)

# %% [markdown]
# **Przyjmujemy, że naszym ryzykiem strategicznym są logarytmiczne stopy zwrotu cen ropy. Przy użyciu tych stóp oraz wyznaczonych prostych regresji, ustalamy nowe zmienne ryzyka dla miedzi oraz aluminium.**

# %%
R1_new = 0.9*r_oil + b1

# %%
R2_new = 0.3*r_oil + b2

# %%
s, E, s_min, E_min, idx = portfolio(R1_new, R2_new)
fig, ax = plt.subplots(figsize = (10, 6))
plt.plot(s, E, color = 'darkgreen', label = 'Portfel o min. ryzyku')
plt.title('Możliwe portfele')
plt.xlabel('$\sigma_p$')
plt.ylabel('$E[R_p]$')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 6))
plt.plot(s, E, color = 'darkgreen', label = 'Możliwe portfele')
plt.scatter(s_min, E_min, color = 'firebrick', label = 'Portfel o min. ryzyku')
plt.title('Możliwe portfele')
plt.xlabel('$\sigma_p$')
plt.ylabel('$E[R_p]$')
plt.legend()
plt.show()

# %%
s_min, E_min
# Out:
# (0.011726882133521174, -0.00041519381739117694)

# %%
round(np.linspace(.01, .99, 99)[idx], 2) #waga 'minimalna' dla miedzi
# Out:
# 0.01

# %%
round((1 - np.linspace(.01, .99, 99))[idx], 2) #waga 'minimalna' dla aluminium
# Out:
# 0.99

# %%
s, E, s_min, E_min, idx = portfolio2(R1_new, R2_new, -0.0003)

portfig, ax = plt.subplots(figsize = (10, 6))
plt.plot(s, E, color = 'darkgreen', label = 'Możliwe portfele')
plt.axline((min(s), E_min), (max(s), E_min), linestyle = 'dashdot', color = 'gray', 
          label = 'Stopa wolna od ryzyka')
plt.scatter(s_min, E_min, color = 'firebrick', label = 'Portfel o min. ryzyku')
plt.title('Możliwe portfele')
plt.xlabel('$\sigma_p$')
plt.ylabel('$E[R_p]$')
plt.legend()
plt.show()

# %%
s_min, E_min
# Out:
# (0.027446732175271417, -0.0003462280222738666)

# %%
round(np.linspace(.001, .999, 999)[idx], 2) #waga 'minimalna' dla miedzi
# Out:
# 1.0

# %%
round((1 - np.linspace(.001, .999, 999))[idx], 2) #waga 'minimalna' dla aluminium
# Out:
# 0.0

# %%
s, E, s_min, E_min, idx = portfolio3(R1_new, R2_new, -0.3,0.009)

portfig, ax = plt.subplots(figsize = (10, 6))
plt.plot(s, E, color = 'darkgreen', label = 'Możliwe portfele')
plt.scatter(s_min, E_min, color = 'firebrick', label = 'Portfel o min. ryzyku')
plt.title('Możliwe portfele')
plt.xlabel('$\sigma_p$')
plt.ylabel('$E[R_p]$')
plt.legend()
plt.show()
